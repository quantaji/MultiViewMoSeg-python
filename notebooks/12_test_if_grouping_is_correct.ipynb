# %%
import numpy as np

# %%
# # case 1: single moving chair, small FoV
# case_id = 1
# idx = 1346
# traj_path = "/scratch/quanta/Experiments/Thesis/exps/prob_video_1/cotracker_dense_8/trajectory_{:06d}.npy".format(idx)
# img_pth = "/scratch/quanta/Experiments/Thesis/exps/prob_video_1/rgb/{:06d}.jpg".format(idx)

# # case 2: ipad and hands, medium FoV
# case_id = 2
# idx = 260
# traj_path = "/scratch/quanta/Experiments/Thesis/exps/prob_video_3/cotracker_dense_8/trajectory_{:06d}.npy".format(idx)
# img_pth = "/scratch/quanta/Experiments/Thesis/exps/prob_video_3/rgb/{:06d}.jpg".format(idx)

# # case 3: no moving things, large FoV
# case_id = 3
# idx = 778
# traj_path = "/scratch/quanta/Experiments/Thesis/exps/prob_video_2/cotracker_dense_8/trajectory_{:06d}.npy".format(idx)
# img_pth = "/scratch/quanta/Experiments/Thesis/exps/prob_video_2/rgb/{:06d}.jpg".format(idx)

# # case 4: two hands and openning of rice-cooker
# case_id = 4
# idx = 360
# traj_path = "/scratch/quanta/Experiments/Thesis/exps/prob_video_2/cotracker_dense_8/trajectory_{:06d}.npy".format(idx)
# img_pth = "/scratch/quanta/Experiments/Thesis/exps/prob_video_2/rgb/{:06d}.jpg".format(idx)

# # case 5: two pans
# case_id = 5
# idx = 2220
# traj_path = "/scratch/quanta/Experiments/Thesis/exps/prob_video_2/cotracker_dense_8/trajectory_{:06d}.npy".format(idx)
# img_pth = "/scratch/quanta/Experiments/Thesis/exps/prob_video_2/rgb/{:06d}.jpg".format(idx)

# case 6: openning of iPad
case_id = 6
idx = 386
traj_path = "/scratch/quanta/Experiments/Thesis/exps/prob_video_3/cotracker_dense_8/trajectory_{:06d}.npy".format(idx)
img_pth = "/scratch/quanta/Experiments/Thesis/exps/prob_video_3/rgb/{:06d}.jpg".format(idx)

traj = np.load(traj_path)[0, 0]
# group = np.load("./group_idx_{:02d}.npy".format(case_id))
group = np.load("./group_idx_dbscan_{:02d}.npy".format(case_id))

# %%
traj.shape, group.shape
# Out:
# ((9801, 2), (9801,))

# %%
from PIL import Image



img_arr = np.array(Image.open(img_pth))

# %%
colors = [
    (0, 255, 0),
    (255, 255, 0),
    (0, 0, 255),
    (255, 0, 0),
    (255, 127, 0),
    (127, 127, 0),
    (0, 127, 0),
    (0, 127, 127),
    (127, 127, 127),
    (127, 0, 127),
    (127, 255, 0),
    (49, 127, 127),
    (127, 127, 36),
    (127, 255, 127),
    (127, 255, 255),
]

# %%
import cv2

# %%
for i in range(traj.shape[0]):
    img_arr = cv2.circle(
        img_arr,
        traj[i].astype(int),
        radius=5,
        color=colors[group[i]],
        thickness=-1,
    )

# %%
display(Image.fromarray(img_arr))
# Out:
# <PIL.Image.Image image mode=RGB size=1280x1280>
